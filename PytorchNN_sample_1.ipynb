# %% [markdown]
# <a href="https://colab.research.google.com/github/Einie-ai/CFD-workspace/blob/main/PytorchNN_sample_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib
import math as mt

a=34;
b=9;

c=mt.pow(a,b);

if (a>b):
  print("the value is = ",c);
elif (a==b)  :
  print("f*** yourselves");
else:
  print("answer is ",a+b);
# Out:
# the value is =  60716992766464.0
